# %% [markdown]
# # 📊 Bank Customer Churn Analysis - Summary Report
#
# ---
# ## 🧾 Executive Summary
#
# This analysis explores customers demographics, customers behaviour (account-wise), the factors influencing customer churn at the bank and evaluates the potential to predict which customers are at risk of leaving. Using historical customer data, a predictive model was built to identify key patterns tied to churn. Age, income level, credit score, account balance, and product usage emerged as the most important indicators of whether a customer is likely to exit. While the model is effective at identifying many churners, there is still room for improvement, especially in capturing all customers who may be considering leaving. Notably, some factors typically seen as less influential, like income, played a larger role in our customer base than expected. These insights provide a foundation for more targeted retention strategies and suggest that deeper behavioral data could further strengthen our ability to proactively reduce churn.
#
#
# ### 1. What attributes are more common among churners than non-churners?
#
# - **Credit Score**: Churners tend to have lower mean credit scores.
# - **Age**: Churners are typically older (ages 40–60).
# - **Tenure**: Customers with shorter tenures are more likely to churn.
# - **Balance**: Churners tend to maintain higher average balances.
# - **Products**: Customers with fewer bank products are more likely to churn.
# - **Active Membership**: Less active customers show higher churn rates.
# - **Churn Prediction**: Churn can be predicted with reasonable accuracy using the variables in the dataset. Based on the Random Forest model's feature importance analysis, Age is the strongest predictor, followed by EstimatedSalary, CreditScore, Balance, and NumOfProducts.
#
# **💡 Inference:**
# Focus retention strategies on older, high-balance, low-tenure, and less engaged customers.
#
# ---
#
# ### 2. What do the overall demographics of the bank's customers look like?
#
# - **Age**: Most customers are aged 30–50; average age is ~38.
# - **Gender**: Slightly more males than females.
# - **Geography**: Most customers are from France, followed by Germany and Spain.
# - **Credit Score**: Generally ranges between 650–700.
# - **Balance & Salary**: Germany shows a higher average balance.
# - **Tenure**: Most customers have between 4 to 6 years of tenure.
#
# **💡 Inference:**
# The bank's primary customer base is mid-aged, moderately tenured, and financially stable, with France being the strongest market.
#
# ---
#
# ### 3. Differences in Behavior Across Germany, France, and Spain
#
# | Country  | Churn Rate | Avg Balance | Avg Tenure | Avg Credit Score | Engagement |
# |----------|------------|-------------|------------|------------------|------------|
# | France   | ~15%       | ~115k       | ~5.0 yrs   | ~660             | High       |
# | Germany  | ~35%       | ~125k       | ~6.2 yrs   | ~680             | Moderate   |
# | Spain    | ~18%       | ~112k       | ~4.3 yrs   | ~645             | Lower      |
#
# **💡 Inference:**
# Germany has the most valuable but at-risk customers. France is the most stable market, while Spain presents growth potential with younger customers.
#
# ---
#
# ### 4. Customer Segments
#
# - **Segment 1: Loyal, Low Risk**
#   Older, long-tenured, and high credit score customers. Low churn risk.
#
# - **Segment 2: At-Risk Professionals**
#   Mid-aged, moderately engaged customers with moderate churn risk.
#
# - **Segment 3: Affluent but Unhappy**
#   High earners with good financial standing (often German) but high churn rates.
#
# - **Segment 4: Young & Unengaged**
#   Recently joined, low-product customers. Low current value, but high growth potential.
#
# **💡 Inference:**
# Apply targeted strategies to improve engagement, loyalty rewards, and cross-sell products per segment.
#
# ---
#
# ## 📌 Key Insights
#
# ### 1. Demographic Distribution by Country and Gender
# - **France** has the highest number of customers.
# - **Gender distribution** is balanced but slightly skewed toward males across all countries.
#
# ### 2. Age and Tenure Trends
# - **Germany** has older customers; **Spain** has a younger population.
# - **Tenure** is more balanced in France; most Spanish and German customers have ≤5 years with the bank.
#
# ### 3. Behavioral Patterns (Country-Specific)
# - **Product usage**: Most customers use 1–2 products.
# - **Active membership**: Higher in France, lower in Germany.
#
# ### 4. Churn and Customer Attitudes
# - **Churn** is higher among older, disengaged customers.
# - **Exited customers** often have wider balance ranges and lower engagement.
#
# ### 5. Feature Importance (Churn Prediction)
# - **Top predictors** of churn:
#   `Age`, `Estimated Salary`, `Credit Score`, `Balance`, `Number of Products`.
#
# ### 6. Segmentation (Cluster Analysis)
# - **Customer clusters by geography** show at least 4 distinct segments with differing churn tendencies, product usage, and demographics.
#
# ---
#
# ## ✅ Recommendations
#
# 1. Target older and inactive members for **engagement campaigns**.
# 2. Explore **product bundling opportunities** to increase multi-product ownership.
# 3. Prioritize **France** as it holds the largest, most stable customer base.
